# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression

# %%
X,y = make_regression(n_samples = 400, n_features=1,noise=1.8, random_state=11)
y = y.reshape((-1,1))
print(X.shape)
print(y.shape)
# Out:
# (400, 1)
# (400, 1)

# %%
X = (X - X.mean())/X.std()

# %%
plt.scatter(X,y)

# %%
ones = np.ones((X.shape[0],1))

# %%
X_ = np.hstack((X,ones))

# %%
X.shape
# Out:
# (400, 1)
